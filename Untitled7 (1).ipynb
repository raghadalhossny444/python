# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Raghad Al Hossny**<br> machine learning engineer

# %% [markdown]
# *I am interested in data science because it's the sexiest jop in the 20th Century.<br>
# And because it will help me to draw my road map for learning AI .*|

# %% [markdown]
# ### my code will find out if a input number is even or odd..

# %%
a= int(input())
if a%2==0 :
    print("even")
else:
    print("odd")

# %% [markdown]
# [instagram](https://www.instagram.com/)<br>
# ![photo_2021-12-23_08-31-12.jpg](attachment:photo_2021-12-23_08-31-12.jpg)
# 1. java
# 2. python
# 3. c++
